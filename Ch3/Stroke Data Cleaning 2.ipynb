# %% [markdown]
# # 3.5.5 시각화

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df = pd.read_csv('healthcare-dataset-2.csv')
df.shape
# Out:
# (3915, 12)

# %%
# 참고 코딩
import seaborn as sns
sns.histplot(data=df, x="age", kde=True, bins=20);

# %%
# 참고 코딩
df['age'].describe()
# Out:
# count    3915.000000
# mean       50.072031
# std        17.462886
# min        19.000000
# 25%        36.000000
# 50%        50.000000
# 75%        63.000000
# max        82.000000
# Name: age, dtype: float64

# %%
import seaborn as sns
sns.histplot(data=df, x="age", hue="stroke", bins=20);

# %%
sns.set_style('whitegrid')
sns.boxplot(x = 'stroke', y = 'age', data = df)

# %%
group = df['age'].groupby(df['stroke'])
group.mean()
# Out:
# stroke
# 0    49.153681
# 1    67.782383
# Name: age, dtype: float64

# %%
# 참고 코딩
from matplotlib import pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(15, 4))

sns.histplot(ax=axes[0], data=df, x="avg_glucose_level", kde=True, bins=20);
sns.histplot(ax=axes[1], data=df, x="bmi", kde=True, bins=20);

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 4))

sns.histplot(ax=axes[0], data=df, x="avg_glucose_level", hue="stroke", bins=20)
sns.histplot(ax=axes[1], data=df, x="bmi", hue="stroke", bins=20);

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 4))

sns.boxplot(ax=axes[0], x = 'stroke', y = 'avg_glucose_level', data = df) 
sns.boxplot(ax=axes[1], x = 'stroke', y = 'bmi', data = df);

# %%
group = df['avg_glucose_level'].groupby(df['stroke'])
group.mean()
# Out:
# stroke
# 0    103.551636
# 1    126.236580
# Name: avg_glucose_level, dtype: float64

# %%
# 참조 코딩
group = df['bmi'].groupby(df['stroke'])
group.mean()
# Out:
# stroke
# 0    30.343391
# 1    30.124352
# Name: bmi, dtype: float64

# %%
# 참조 코딩
fig, axes = plt.subplots(1, 2, figsize=(8, 4))

sns.countplot(ax=axes[0], x='gender', data=df)
sns.countplot(ax=axes[1], x='gender', hue='stroke', data=df);

# %%
# 참조 코딩
fig, axes = plt.subplots(1, 2, figsize=(8, 4))

sns.countplot(ax=axes[0], x='hypertension', data=df)
sns.countplot(ax=axes[1], x='hypertension', hue='stroke', data=df);

# %%
# 참조 코딩
fig, axes = plt.subplots(1, 2, figsize=(8, 4))

sns.countplot(ax=axes[0], x='heart_disease', data=df)
sns.countplot(ax=axes[1], x='heart_disease', hue='stroke', data=df);

# %%
# 참조 코딩
fig, axes = plt.subplots(1, 2, figsize=(8, 4))

sns.countplot(ax=axes[0], x='ever_married', data=df)
sns.countplot(ax=axes[1], x='ever_married', hue='stroke', data=df);

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

sns.countplot(ax=axes[0], x='work_type', data=df)
sns.countplot(ax=axes[1], x='work_type', hue='stroke', data=df);

# %%
# 참조 코딩
fig, axes = plt.subplots(1, 2, figsize=(8, 4))

sns.countplot(ax=axes[0], x='residence_type', data=df)
sns.countplot(ax=axes[1], x='residence_type', hue='stroke', data=df);

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

sns.countplot(ax=axes[0], x='smoking_status', data=df)
sns.countplot(ax=axes[1], x='smoking_status', hue='stroke', data=df);

# %% [markdown]
# # 3.5.6 t 검정

# %%
from scipy import stats

data_1 = df[df['stroke'] == 1]['age']
data_0 = df[df['stroke'] == 0]['age']

stats.ttest_ind(data_1, data_0)   # 결과는 pvalue < 0.05
# Out:
# Ttest_indResult(statistic=14.84966867789424, pvalue=1.4355395712390346e-48)

# %%
from scipy import stats

data_1 = df[df['stroke'] == 1]['avg_glucose_level']
data_0 = df[df['stroke'] == 0]['avg_glucose_level']

stats.ttest_ind(data_1, data_0)   # 결과는 pvalue < 0.05
# Out:
# Ttest_indResult(statistic=7.200791069659755, pvalue=7.144119062259364e-13)

# %%
from scipy import stats

data_1 = df[df['stroke'] == 1]['bmi']
data_0 = df[df['stroke'] == 0]['bmi']

stats.ttest_ind(data_1, data_0)   # 결과는 pvalue > 0.05
# Out:
# Ttest_indResult(statistic=-0.42810612400712617, pvalue=0.6685974193789274)

# %%
df['stroke'].dtype
# Out:
# dtype('int64')
